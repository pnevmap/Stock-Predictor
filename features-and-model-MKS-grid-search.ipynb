# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn import grid_search
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge 
from sklearn.svm import LinearSVR
# Out:
# C:\Playground\venvs\mlnd-capstone-363\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Playground\venvs\mlnd-capstone-363\lib\site-packages\sklearn\grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# ### Data Preprcessing

# %%
mks = pd.read_csv("data/MKSfull.csv")

# %%
#data preprocessing 
#remove NaN values
nans = mks[mks['Close'].isnull()]
mks.drop(nans.index, inplace=True)

# %% [markdown]
# ### Create Features Dataframes

# %%
def create_dataframes(X_len, days):
    use = mks.tail(X_len + days)
    Χ_columns = []
    for j in range(days):
        Χ_columns.append('i+%s' % str(j))

    X = pd.DataFrame(index=range(X_len),columns = Χ_columns)
    y = pd.DataFrame(index=range(X_len), columns = ['Close'])

    for i in range(X_len):
        for j in range(days):
            X.iloc[i]['i+%s' % str(j)] = use.iloc[i + j]['Close']
        y.iloc[i] = use.iloc[(i + j + 1)]['Close']
        
    return X, y

# %%
def create_dataframes_ta(X_len, days):
    use = mks.tail(X_len + days)
    Χ_columns = []
    for j in range(days):
        Χ_columns.append('i+%s' % str(j))
    
    Χ_columns.append('Range')
    Χ_columns.append('Change')
    Χ_columns.append('ChangePercentage')
    
    X = pd.DataFrame(index=range(X_len),columns = Χ_columns)
    y = pd.DataFrame(index=range(X_len), columns = ['Close'])

    for i in range(X_len):
        stock_range = []
        stock_change = []
        stock_change_perc = []        
        for j in range(days):
            X.iloc[i]['i+%s' % str(j)] = use.iloc[i + j]['Close']
            stock_range.append(use.iloc[i + j]['High'] - use.iloc[i + j]['Low'])
            stock_change.append(use.iloc[i + j]['Close'] - use.iloc[i + j]['Open'])
            stock_change_perc.append(((use.iloc[i + j]['Close'] - use.iloc[i + j]['Open']) / use.iloc[i + j]['Open'])* 100) 

        X.iloc[i]['Range'] = np.mean(stock_range)
        X.iloc[i]['Change'] = np.mean(stock_change)
        X.iloc[i]['ChangePercentage'] = np.mean(stock_change_perc)
        y.iloc[i] = use.iloc[(i + j + 1)]['Close']
        
    return X, y

# %% [markdown]
# ### Split train/test set

# %%
def split_train_test_set(X, y, test_size=0.3):  
    if len(X) != len(y):
        return "Error"
    split_index = int(len(X) * (1-test_size))
    X_train = X[:split_index]
    X_test = X[split_index:]
    y_train = y[:split_index]
    y_test = y[split_index:]
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ### Define metrics

# %%
def rmse(test, pred):
    return np.sqrt(((test - pred) ** 2).mean())

# %% [markdown]
# ### Benchmark model, persistence

# %%
def identity(x):
    return x

def model_persistence(test_X, days):
    predictions = list()
    for x in test_X['i+%s' % str(days-1)]:
        yhat = identity(x)
        predictions.append(yhat)
    return predictions

# %% [markdown]
# ### Define, Train Regressors: Linear, Ridge, Linear SVM

# %%
def get_linear_model(X, y):
    regressor = LinearRegression()
    parameters = {'fit_intercept':[True, False], 'normalize':[True, False], 'copy_X':[True, False]}
    grid = GridSearchCV(regressor, parameters)
    grid.fit(X, y)
    return grid.best_estimator_

def get_ridge_model(X, y):
    r_reg = Ridge()
    r_reg.fit(X, y)
    return r_reg

def get_lsvr_model(X, y):
    svr = LinearSVR()
    svr.fit(X, y.values.ravel())
    return svr

# %% [markdown]
# ### Grid Search for days, data set size, usage of technical analysis features

# %%
i = 0
result = pd.DataFrame(index=range(60),columns = ['UseTA', 'days', 'X_size','Benchmark', 'Linear', 'Linear_Train', 'Ridge', 'Ridge_Train','LSVR', 'LSVR_Train'])
for use_ta in [True, False]:
    for days in [10, 15, 20]:
        for X_size in [100, 300, 500, 800, 1000, 1200, 1500, 2000, 3000, 7000]:
            X = []
            y = []
            print('iteration {0}'.format(i))
            if use_ta: 
                X,y = create_dataframes_ta(X_size, days)
            else: 
                X,y = create_dataframes(X_size, days)

            X_train, X_test, y_train, y_test = split_train_test_set(X, y)

            benchmark_pred = model_persistence(X_test,days )
            benchmark_err = rmse(y_test['Close'], benchmark_pred)

            linear_model = get_linear_model(X_train, y_train)
            lr_pred = linear_model.predict(X_test)
            lr_err = rmse(y_test, lr_pred)
            lr_pred_train = linear_model.predict(X_train)
            lr_err_train = rmse(y_train, lr_pred_train)

            
            ridge_model = get_ridge_model(X_train, y_train)
            rr_pred = ridge_model.predict(X_test)
            rr_err = rmse(y_test, rr_pred)
            rr_pred_train = ridge_model.predict(X_train)
            rr_err_train = rmse(y_train, rr_pred_train)
            

            lsvr_model = get_lsvr_model(X_train, y_train)
            lsvr_pred = lsvr_model.predict(X_test)
            lsvr_err = rmse(y_test.values.ravel(), lsvr_pred)
            lsvr_pred_train = lsvr_model.predict(X_train)
            lsvr_err_train = rmse(y_train.values.ravel(), lsvr_pred_train)
            

            result.iloc[i]['UseTA'] = str(use_ta)
            result.iloc[i]['days'] = days
            result.iloc[i]['X_size'] = X_size
            result.iloc[i]['Benchmark'] = benchmark_err
            
            result.iloc[i]['Linear'] = float(lr_err)
            result.iloc[i]['Linear_Train'] = float(lr_err_train)            
            
            result.iloc[i]['Ridge'] = float(rr_err)
            result.iloc[i]['Ridge_Train'] = float(rr_err_train)
            
            result.iloc[i]['LSVR'] = float(lsvr_err)
            result.iloc[i]['LSVR_Train'] = float(lsvr_err_train)
            
            #result.iloc[i]['coefs'] = linear_model.coef_
            print (result.iloc[i])
            i = i + 1
            
result
# Out:
# iteration 0
# UseTA              True
# days                 10
# X_size              100
# Benchmark       4.09834
# Linear          5.04258
# Linear_Train    3.60864
# Ridge           5.06587
# Ridge_Train     3.44433
# LSVR            5.03487
# LSVR_Train      4.76473
# Name: 0, dtype: object
# iteration 1
# UseTA              True
# days                 10
# X_size              300
# Benchmark       4.05541
# Linear          4.13512
# Linear_Train    4.98057
# Ridge           4.10876
# Ridge_Train      4.9684
# LSVR            4.62711
# LSVR_Train       5.4628
# Name: 1, dtype: object
# iteration 2
# UseTA              True
# days                 10
# X_size              500
# Benchmark       4.44984
# Linear          4.77824
# Linear_Train    7.01418
# Ridge           4.78602
# Ridge_Train     7.01431
# LSVR            11.1618
# LSVR_Train      12.9177
# Name: 2, dtype: object
# iteration 3
# UseTA              True
# days                 10
# X_size              800
# Benchmark       4.56521
# Linear          4.83362
# Linear_Train    7.37212
# Ridge           4.80212
# Ridge_Train     7.37316
# LSVR            4.79076
# LSVR_Train      7.47794
# Name: 3, dtype: object
# iteration 4
# UseTA              True
# days                 10
# X_size             1000
# Benchmark       4.79599
# Linear          5.08474
# Linear_Train      7.213
# Ridge           5.04733
# Ridge_Train     7.21312
# LSVR            5.02884
# LSVR_Train      7.32849
# Name: 4, dtype: object
# iteration 5
# UseTA              True
# days                 10
# X_size             1200
# Benchmark       5.12383
# Linear          5.32725
# Linear_Train    7.26221
# Ridge             5.357
# Ridge_Train     7.25792
# LSVR            9.56173
# LSVR_Train      13.2062
# Name: 5, dtype: object
# iteration 6
# UseTA              True
# days                 10
# X_size             1500
# Benchmark       6.52561
# Linear          6.54513
# Linear_Train    6.38926
# Ridge           6.54922
# Ridge_Train     6.38931
# LSVR            10.0634
# LSVR_Train      11.3874
# Name: 6, dtype: object
# iteration 7
# UseTA              True
# days                 10
# X_size             2000
# Benchmark       6.72916
# Linear          6.72558
# Linear_Train    6.04491
# Ridge           6.72431
# Ridge_Train     6.04089
# LSVR            7.95609
# LSVR_Train      7.28381
# Name: 7, dtype: object
# iteration 8
# UseTA              True
# days                 10
# X_size             3000
# Benchmark       6.78857
# Linear          6.82093
# Linear_Train    7.75065
# Ridge           6.82091
# Ridge_Train     7.75065
# LSVR             7.3322
# LSVR_Train      8.32901
# Name: 8, dtype: object
# iteration 9
# UseTA              True
# days                 10
# X_size             7000
# Benchmark       6.28203
# Linear          6.28725
# Linear_Train    8.02582
# Ridge           6.28425
# Ridge_Train     8.02188
# LSVR            11.6684
# LSVR_Train      13.9245
# Name: 9, dtype: object
# iteration 10
# UseTA              True
# days                 15
# X_size              100
# Benchmark       4.09834
# Linear          5.24153
# Linear_Train    3.51486
# Ridge           6.13333
# Ridge_Train     3.25942
# LSVR            5.34439
# LSVR_Train      4.69465
# Name: 10, dtype: object
# iteration 11
# UseTA              True
# days                 15
# X_size              300
# Benchmark       4.05541
# Linear          4.40692
# Linear_Train    4.92092
# Ridge           4.19052
# Ridge_Train     4.90725
# LSVR            6.80744
# LSVR_Train      7.58512
# Name: 11, dtype: object
# iteration 12
# UseTA              True
# days                 15
# X_size              500
# Benchmark       4.44984
# Linear          4.71341
# Linear_Train     7.0239
# Ridge           4.72163
# Ridge_Train      7.0241
# LSVR            5.17122
# LSVR_Train       7.4798
# Name: 12, dtype: object
# iteration 13
# UseTA              True
# days                 15
# X_size              800
# Benchmark       4.56521
# Linear          4.82629
# Linear_Train    7.33146
# Ridge           4.78621
# Ridge_Train      7.3328
# LSVR            4.81616
# LSVR_Train      7.48678
# Name: 13, dtype: object
# iteration 14
# UseTA              True
# days                 15
# X_size             1000
# Benchmark       4.79599
# Linear          5.06197
# Linear_Train    7.17593
# Ridge           5.01515
# Ridge_Train     7.17693
# LSVR            9.06723
# LSVR_Train      12.5528
# Name: 14, dtype: object
# iteration 15
# UseTA              True
# days                 15
# X_size             1200
# Benchmark       5.12383
# Linear          5.23092
# Linear_Train    7.23718
# Ridge           5.35309
# Ridge_Train     7.22912
# LSVR            5.64603
# LSVR_Train       7.8588
# Name: 15, dtype: object
# iteration 16
# UseTA              True
# days                 15
# X_size             1500
# Benchmark       6.52561
# Linear          6.49985
# Linear_Train     6.3718
# Ridge           6.55606
# Ridge_Train     6.35774
# LSVR            24.5189
# LSVR_Train      30.4983
# Name: 16, dtype: object
# iteration 17
# UseTA              True
# days                 15
# X_size             2000
# Benchmark       6.72916
# Linear          6.75246
# Linear_Train    6.02895
# Ridge           6.75325
# Ridge_Train     6.02437
# LSVR            6.88734
# LSVR_Train      6.34763
# Name: 17, dtype: object
# iteration 18
# UseTA              True
# days                 15
# X_size             3000
# Benchmark       6.78857
# Linear          6.82185
# Linear_Train    7.73727
# Ridge           6.82185
# Ridge_Train     7.73727
# LSVR            6.92916
# LSVR_Train      7.88071
# Name: 18, dtype: object
# iteration 19
# UseTA              True
# days                 15
# X_size             7000
# Benchmark       6.28203
# Linear          6.29693
# Linear_Train    8.02005
# Ridge           6.29412
# Ridge_Train      8.0165
# LSVR            7.70049
# LSVR_Train      9.47269
# Name: 19, dtype: object
# iteration 20
# UseTA              True
# days                 20
# X_size              100
# Benchmark       4.09834
# Linear          4.84827
# Linear_Train    3.36852
# Ridge           6.63131
# Ridge_Train     2.98973
# LSVR            6.66352
# LSVR_Train      6.51175
# Name: 20, dtype: object
# iteration 21
# UseTA              True
# days                 20
# X_size              300
# Benchmark       4.05541
# Linear          4.39414
# Linear_Train    4.80965
# Ridge           4.28455
# Ridge_Train     4.82767
# LSVR            4.48231
# LSVR_Train      5.15005
# Name: 21, dtype: object
# iteration 22
# UseTA              True
# days                 20
# X_size              500
# Benchmark       4.44984
# Linear          4.67984
# Linear_Train    6.94482
# Ridge           4.70707
# Ridge_Train     6.94935
# LSVR            9.44853
# LSVR_Train      11.2232
# Name: 22, dtype: object
# iteration 23
# UseTA              True
# days                 20
# X_size              800
# Benchmark       4.56521
# Linear           4.8749
# Linear_Train    7.28383
# Ridge           4.81388
# Ridge_Train     7.28554
# LSVR            5.25906
# LSVR_Train      7.95028
# Name: 23, dtype: object
# iteration 24
# UseTA              True
# days                 20
# X_size             1000
# Benchmark       4.79599
# Linear           5.0701
# Linear_Train    7.13477
# Ridge           4.99914
# Ridge_Train     7.13758
# LSVR            6.60571
# LSVR_Train      9.35021
# Name: 24, dtype: object
# iteration 25
# UseTA              True
# days                 20
# X_size             1200
# Benchmark       5.12383
# Linear          5.29201
# Linear_Train    7.19088
# Ridge           5.41656
# Ridge_Train      7.1835
# LSVR            6.37629
# LSVR_Train       8.8537
# Name: 25, dtype: object
# iteration 26
# UseTA              True
# days                 20
# X_size             1500
# Benchmark       6.52561
# Linear          6.57799
# Linear_Train    6.32337
# Ridge            6.5768
# Ridge_Train     6.32337
# LSVR            6.97067
# LSVR_Train      6.87839
# Name: 26, dtype: object
# iteration 27
# UseTA              True
# days                 20
# X_size             2000
# Benchmark       6.72916
# Linear          6.76287
# Linear_Train    6.01575
# Ridge           6.75585
# Ridge_Train     6.01133
# LSVR            8.21779
# LSVR_Train       7.5608
# Name: 27, dtype: object
# iteration 28
# UseTA              True
# days                 20
# X_size             3000
# Benchmark       6.78857
# Linear          6.82646
# Linear_Train    7.73448
# Ridge           6.82647
# Ridge_Train     7.73448
# LSVR            6.84623
# LSVR_Train      7.77194
# Name: 28, dtype: object
# iteration 29
# UseTA              True
# days                 20
# X_size             7000
# Benchmark       6.28203
# Linear           6.3092
# Linear_Train    8.00785
# Ridge           6.30667
# Ridge_Train     8.00465
# LSVR            20.1432
# LSVR_Train      23.3732
# Name: 29, dtype: object
# iteration 30
# UseTA             False
# days                 10
# X_size              100
# Benchmark       4.09834
# Linear          4.93059
# Linear_Train    3.53602
# Ridge           4.92935
# Ridge_Train     3.53602
# LSVR             4.8932
# LSVR_Train      3.89018
# Name: 30, dtype: object
# iteration 31
# UseTA             False
# days                 10
# X_size              300
# Benchmark       4.05541
# Linear          4.09929
# Linear_Train    4.97364
# Ridge           4.09933
# Ridge_Train     4.97364
# LSVR            4.35012
# LSVR_Train      5.20939
# Name: 31, dtype: object
# iteration 32
# UseTA             False
# days                 10
# X_size              500
# Benchmark       4.44984
# Linear          4.53445
# Linear_Train    7.12103
# Ridge           4.53443
# Ridge_Train     7.12103
# LSVR            7.91913
# LSVR_Train      10.3383
# Name: 32, dtype: object
# iteration 33
# UseTA             False
# days                 10
# X_size              800
# Benchmark       4.56521
# Linear             4.69
# Linear_Train    7.42478
# Ridge           4.68737
# Ridge_Train     7.42351
# LSVR             4.7247
# LSVR_Train      7.46431
# Name: 33, dtype: object
# iteration 34
# UseTA             False
# days                 10
# X_size             1000
# Benchmark       4.79599
# Linear            4.931
# Linear_Train    7.26284
# Ridge           4.93113
# Ridge_Train     7.26045
# LSVR            5.65734
# LSVR_Train      8.09782
# Name: 34, dtype: object
# iteration 35
# UseTA             False
# days                 10
# X_size             1200
# Benchmark       5.12383
# Linear          5.18457
# Linear_Train    7.30051
# Ridge           5.22544
# Ridge_Train     7.29355
# LSVR            7.56338
# LSVR_Train      10.5726
# Name: 35, dtype: object
# iteration 36
# UseTA             False
# days                 10
# X_size             1500
# Benchmark       6.52561
# Linear          6.54894
# Linear_Train    6.39181
# Ridge           6.54895
# Ridge_Train     6.39181
# LSVR            6.99657
# LSVR_Train      7.05613
# Name: 36, dtype: object
# iteration 37
# UseTA             False
# days                 10
# X_size             2000
# Benchmark       6.72916
# Linear          6.74474
# Linear_Train    6.05416
# Ridge           6.74106
# Ridge_Train     6.04998
# LSVR            6.72484
# LSVR_Train       6.0958
# Name: 37, dtype: object
# iteration 38
# UseTA             False
# days                 10
# X_size             3000
# Benchmark       6.78857
# Linear          6.80571
# Linear_Train    7.76451
# Ridge           6.80571
# Ridge_Train     7.76451
# LSVR            6.81195
# LSVR_Train      7.78538
# Name: 38, dtype: object
# iteration 39
# UseTA             False
# days                 10
# X_size             7000
# Benchmark       6.28203
# Linear          6.27628
# Linear_Train    8.03093
# Ridge           6.27628
# Ridge_Train     8.03093
# LSVR            7.97318
# LSVR_Train      9.77754
# Name: 39, dtype: object
# iteration 40
# UseTA             False
# days                 15
# X_size              100
# Benchmark       4.09834
# Linear           5.0657
# Linear_Train    3.45755
# Ridge           5.06533
# Ridge_Train     3.45756
# LSVR            5.32892
# LSVR_Train      3.93668
# Name: 40, dtype: object
# iteration 41
# UseTA             False
# days                 15
# X_size              300
# Benchmark       4.05541
# Linear          4.17453
# Linear_Train    4.91491
# Ridge           4.17457
# Ridge_Train     4.91491
# LSVR            5.10325
# LSVR_Train      5.70171
# Name: 41, dtype: object
# iteration 42
# UseTA             False
# days                 15
# X_size              500
# Benchmark       4.44984
# Linear          4.54616
# Linear_Train    7.09843
# Ridge           4.54615
# Ridge_Train     7.09843
# LSVR            7.81117
# LSVR_Train      9.74185
# Name: 42, dtype: object
# iteration 43
# UseTA             False
# days                 15
# X_size              800
# Benchmark       4.56521
# Linear          4.70329
# Linear_Train    7.37708
# Ridge           4.70045
# Ridge_Train     7.37592
# LSVR            6.89402
# LSVR_Train       10.016
# Name: 43, dtype: object
# iteration 44
# UseTA             False
# days                 15
# X_size             1000
# Benchmark       4.79599
# Linear          4.92462
# Linear_Train    7.22675
# Ridge           4.92525
# Ridge_Train     7.22411
# LSVR            5.73427
# LSVR_Train      8.19824
# Name: 44, dtype: object
# iteration 45
# UseTA             False
# days                 15
# X_size             1200
# Benchmark       5.12383
# Linear          5.17862
# Linear_Train    7.26739
# Ridge           5.23583
# Ridge_Train     7.25863
# LSVR            5.91337
# LSVR_Train      8.23452
# Name: 45, dtype: object
# iteration 46
# UseTA             False
# days                 15
# X_size             1500
# Benchmark       6.52561
# Linear          6.51709
# Linear_Train    6.38148
# Ridge           6.55082
# Ridge_Train     6.36861
# LSVR            6.99734
# LSVR_Train      7.30102
# Name: 46, dtype: object
# iteration 47
# UseTA             False
# days                 15
# X_size             2000
# Benchmark       6.72916
# Linear          6.76299
# Linear_Train    6.03755
# Ridge            6.7604
# Ridge_Train     6.03237
# LSVR            10.0558
# LSVR_Train      10.4782
# Name: 47, dtype: object
# iteration 48
# UseTA             False
# days                 15
# X_size             3000
# Benchmark       6.78857
# Linear          6.79881
# Linear_Train    7.75291
# Ridge           6.79881
# Ridge_Train     7.75291
# LSVR            26.8016
# LSVR_Train      28.2882
# Name: 48, dtype: object
# iteration 49
# UseTA             False
# days                 15
# X_size             7000
# Benchmark       6.28203
# Linear           6.2859
# Linear_Train    8.02566
# Ridge            6.2859
# Ridge_Train     8.02566
# LSVR             7.0382
# LSVR_Train       8.7824
# Name: 49, dtype: object
# iteration 50
# UseTA             False
# days                 20
# X_size              100
# Benchmark       4.09834
# Linear          4.78997
# Linear_Train    3.29471
# Ridge           4.78963
# Ridge_Train     3.29472
# LSVR            5.72123
# LSVR_Train      4.45266
# Name: 50, dtype: object
# iteration 51
# UseTA             False
# days                 20
# X_size              300
# Benchmark       4.05541
# Linear          4.35568
# Linear_Train    4.87936
# Ridge           4.28721
# Ridge_Train     4.83278
# LSVR            5.11574
# LSVR_Train      5.79044
# Name: 51, dtype: object
# iteration 52
# UseTA             False
# days                 20
# X_size              500
# Benchmark       4.44984
# Linear          4.57592
# Linear_Train    7.03185
# Ridge           4.57589
# Ridge_Train     7.03185
# LSVR            5.52515
# LSVR_Train      7.71445
# Name: 52, dtype: object
# iteration 53
# UseTA             False
# days                 20
# X_size              800
# Benchmark       4.56521
# Linear          4.73294
# Linear_Train    7.32884
# Ridge           4.72953
# Ridge_Train     7.32735
# LSVR            6.54765
# LSVR_Train      9.56383
# Name: 53, dtype: object
# iteration 54
# UseTA             False
# days                 20
# X_size             1000
# Benchmark       4.79599
# Linear          4.92021
# Linear_Train     7.1841
# Ridge           4.91953
# Ridge_Train     7.18184
# LSVR            4.96791
# LSVR_Train      7.29206
# Name: 54, dtype: object
# iteration 55
# UseTA             False
# days                 20
# X_size             1200
# Benchmark       5.12383
# Linear          5.18069
# Linear_Train     7.2279
# Ridge           5.22457
# Ridge_Train     7.22093
# LSVR            5.49344
# LSVR_Train      7.67248
# Name: 55, dtype: object
# iteration 56
# UseTA             False
# days                 20
# X_size             1500
# Benchmark       6.52561
# Linear           6.5363
# Linear_Train    6.34439
# Ridge           6.56891
# Ridge_Train     6.33269
# LSVR            6.54296
# LSVR_Train      6.38042
# Name: 56, dtype: object
# iteration 57
# UseTA             False
# days                 20
# X_size             2000
# Benchmark       6.72916
# Linear          6.76777
# Linear_Train    6.02338
# Ridge           6.76342
# Ridge_Train      6.0193
# LSVR            14.2076
# LSVR_Train      14.2296
# Name: 57, dtype: object
# iteration 58
# UseTA             False
# days                 20
# X_size             3000
# Benchmark       6.78857
# Linear          6.80264
# Linear_Train     7.7499
# Ridge           6.80264
# Ridge_Train      7.7499
# LSVR            13.7941
# LSVR_Train      14.7263
# Name: 58, dtype: object
# iteration 59
# UseTA             False
# days                 20
# X_size             7000
# Benchmark       6.28203
# Linear          6.30255
# Linear_Train     8.0147
# Ridge           6.30255
# Ridge_Train      8.0147
# LSVR            6.56106
# LSVR_Train      8.26015
# Name: 59, dtype: object
#     UseTA days X_size Benchmark   Linear Linear_Train    Ridge Ridge_Train  \
# 0    True   10    100   4.09834  5.04258      3.60864  5.06587     3.44433
# 1    True   10    300   4.05541  4.13512      4.98057  4.10876      4.9684
